# %% [markdown]
# # Basic Operations on Images

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
BLUE = [0,0,255]
img1 = cv2.imread('dog.jpg')

# %%
m=100
replicate = cv2.copyMakeBorder(img1,m,m,m,m,cv2.BORDER_REPLICATE)
reflect = cv2.copyMakeBorder(img1,m,m,m,m,cv2.BORDER_REFLECT)
reflect101 = cv2.copyMakeBorder(img1,m,m,m,m,cv2.BORDER_REFLECT_101)
wrap = cv2.copyMakeBorder(img1,m,m,m,m,cv2.BORDER_WRAP)
constant= cv2.copyMakeBorder(img1,m,m,m,m,cv2.BORDER_CONSTANT,value=BLUE)

# %%
plt.figure(figsize=(12,9))
plt.subplot(231),plt.imshow(img1,'gray'),plt.title('ORIGINAL')
plt.subplot(232),plt.imshow(replicate,'gray'),plt.title('REPLICATE')
plt.subplot(233),plt.imshow(reflect,'gray'),plt.title('REFLECT')
plt.subplot(234),plt.imshow(reflect101,'gray'),plt.title('REFLECT_101')
plt.subplot(235),plt.imshow(wrap,'gray'),plt.title('WRAP')
plt.subplot(236),plt.imshow(constant,'gray'),plt.title('CONSTANT')
plt.show()

# %% [markdown]
# ## addWeighted

# %%
img1 = cv2.imread('dog.jpg')
img2 = cv2.imread('cat.jpg')
dst = cv2.addWeighted(img1,0.7,img2,0.3,0)
cv2.imshow('dst',dst)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-5-f9cb34091fdb> in <module>
#       1 img1 = cv2.imread('dog.jpg')
#       2 img2 = cv2.imread('cat.jpg')
# ----> 3 dst = cv2.addWeighted(img1,0.7,img2,0.3,0)
#       4 cv2.imshow('dst',dst)
#       5 cv2.waitKey(0)
#
# error: OpenCV(4.4.0) C:\Users\appveyor\AppData\Local\Temp\1\pip-req-build-9d_dfo3_\opencv\modules\core\src\arithm.cpp:669: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and the same number of channels), nor 'array op scalar', nor 'scalar op array' in function 'cv::arithm_op'

# %%
def nothing(x):
    pass

# %%
cv2.namedWindow('image')
cv2.createTrackbar('alpha','image',0,255,nothing)
while(1):
    cv2.imshow('image',dst)
    k = cv2.waitKey(1) & 0xFF
    if k == 27:
        break
    alpha = cv2.getTrackbarPos('alpha','image')
    det = cv2.addWeighted(img1,alpha/255.,img2,1.-alpha/255.,0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-5d5de700223f> in <module>
#       2 cv2.createTrackbar('alpha','image',0,255,nothing)
#       3 while(1):
# ----> 4     cv2.imshow('image',dst)
#       5     k = cv2.waitKey(1) & 0xFF
#       6     if k == 27:
#
# NameError: name 'dst' is not defined

# %% [markdown]
# ## Measuring Performance with OpenCV

# %%
img1 = cv2.imread('lena.png')
e1 = cv2.getTickCount()
for i in range(5,49,2):
    img1 = cv2.medianBlur(img1,i)
e2 = cv2.getTickCount()
t = (e2 - e1)/cv2.getTickFrequency()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-8e418c3f40e7> in <module>
# ----> 1 img1 = cv2.imread('lena.png')
#       2 e1 = cv2.getTickCount()
#       3 for i in range(5,49,2):
#       4     img1 = cv2.medianBlur(img1,i)
#       5 e2 = cv2.getTickCount()
#
# NameError: name 'cv2' is not defined

# %%
e1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-eff9d613b2d7> in <module>
# ----> 1 e1
#
# NameError: name 'e1' is not defined

# %%
e2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-4a078b075f25> in <module>
# ----> 1 e2
#
# NameError: name 'e2' is not defined

# %%
print (t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-dea2fd0e44f4> in <module>
# ----> 1 print (t)
#
# NameError: name 't' is not defined

# %%
imageshow(img1)

# %%
import cv2

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
def nothing(x):
    pass

# %%
cv2.namedWindow('image')
cv2.createTrackbar('medianBlur','image',5,49,nothing)
img1 = cv2.imread('dog.jpg')
i=5
while(1):
    i = cv2.getTrackbarPos('medianBlur','image')
    i = int(i/2)*2+1;
    dst = cv2.medianBlur(img1,i)
    cv2.imshow('image',dst)
    k = cv2.waitKey(1) & 0xFF
    if k == 27:
        break
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-873aa16c3f51> in <module>
# ----> 1 cv2.namedWindow('image')
#       2 cv2.createTrackbar('medianBlur','image',5,49,nothing)
#       3 img1 = cv2.imread('dog.jpg')
#       4 i=5
#       5 while(1):
#
# NameError: name 'cv2' is not defined

# %%
4/2
# Out:
# 2.0

# %%
int(4/2)+1
# Out:
# 3
